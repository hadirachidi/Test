# %% [markdown]
# <a href="https://colab.research.google.com/github/hadirachidi/Test/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
print(x)
# Out:
# 5
